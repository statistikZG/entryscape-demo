# %%
from rdflib import Graph

# %%
catalog_url = "https://zg-demo.entryscape.net/store/1"
resource_id = "7"

# %%
g = Graph()
# Parse dataset RDF
dataset_url = f"{catalog_url}/resource/{resource_id}"
g.parse(dataset_url)
g.print(format="turtle")
# Out:
# @prefix : <http://data.europa.eu/r5r/> .
# @prefix dcat: <http://www.w3.org/ns/dcat#> .
# @prefix dcterms: <http://purl.org/dc/terms/> .
#
# <https://zg-demo.entryscape.net/store/1/resource/7> a dcat:Distribution ;
#     :availability <http://data.europa.eu/r5r/availability/temporary> ;
#     dcterms:format <http://publications.europa.eu/resource/authority/file-type/CSV> ;
#     dcterms:license <http://dcat-ap.ch/vocabulary/licenses/terms_by> ;
#     dcterms:title "Test Distribution"@en ;
#     dcat:accessURL <https://zg-demo.entryscape.net/store/1/resource/6> ;
#     dcat:downloadURL <https://zg-demo.entryscape.net/store/1/resource/6> .
